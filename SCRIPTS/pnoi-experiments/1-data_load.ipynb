# %% [markdown]
# # Load Pnoi Sync data

# %%
import pandas as pd
import os


mkdir = lambda p: 0 if os.path.exists(p) else (os.mkdir(p), 1)[1]

# %% [markdown]
# ## Paths to Dataset

# %%
EXP_VER = "v9"

REPORTS = "reports"; mkdir(REPORTS) # Path to the reports folder

PNOI_CORPUS_CSV_NAME = "pnoicorpus_muster.csv" # Name of the csv file

PNOI_CORPUS_CSV_PATH = f"{REPORTS}/{PNOI_CORPUS_CSV_NAME}" # Path to the master csv file

PNOI_SYNC_CSV_NAME = f"pnoi_sync_aud_{EXP_VER}.csv" # Name of the csv file
PNOI_SYNC_CSV_PATH = f"{REPORTS}/{PNOI_SYNC_CSV_NAME}" # Path to the master csv file

# %%
class DataStaticInfo:

    VER = "*"
    SEP = "-"
    META_SEP = "_"
    EXT_SEP = "."
    ANOT_LABELS = ["aa", "ee", "uu", "oo", "ii", "xx", "bb1", "bb2", "bb3", "bb4"]

    fkeys = {
        "APP_CODE": "app_code",
        "SID":"sub_id",
        "FCLASS": "file_class",
        "FID": "file_ID",
        "COMNT": "file_comment",
        "FFMT": "file_format",
        "FNAME": "file_name",
        "FPATH": "file_path",
        "FMATCH": "file_match"
    }

class AudStaticData(DataStaticInfo):
    EMPTY_VAL = '-'
    FNAME_SEP = "-"
    ANOT_SEP = '\t'
    FS_k = "fs"
    BEGIN_k = "begin"; END_k = "end"; LABEL_k = "label"
    ANOTE_COLS = [BEGIN_k, END_k, LABEL_k]

    LUNG_LOCS = ["LU", "RU", "LL", "RL"]

    LBA_k = "LBA"; VBA_k = "VBA"; BA_k = "BA"
    
    AUD_TAG = "aud--"
    ANOT_TAG = "anot--"
    AUDIO_FPATH_k = f"audio--file_path"
    ANOT_FPATH_k = f"anot--file_path"

EXP_VER = "v9"

# %%
class AnotFrame(AudStaticData):


    PNOI_SYNC_DF: pd.DataFrame

    def __init__(self, sync_aud_csv_path: str) -> None:
        self.PNOI_SYNC_DF = pd.read_csv(sync_aud_csv_path)


    def extract_anots(self, row: pd.Series) -> pd.DataFrame:
        anot_path = row[self.ANOT_FPATH_k]
        anot_class = (self.SEP)[2]



    
    def make_dataframe(self) -> pd.DataFrame:
        
        for i, row in self.PNOI_SYNC_DF.iterrows():
            return row


pnoidata_anotframe = AnotFrame(PNOI_SYNC_CSV_PATH)

pnoidata_anotframe.make_dataframe().to_dict()
# Out:
# {'Unnamed: 0': 0,
#  'fs': 16000,
#  'sub_id': 'shreyamgupta_78aa423a',
#  'file_class': '_before_LU',
#  'audio--file_path': 'reports/pnoi_sync_data_v9/shreyamgupta_78aa423a/pnoistor_feb2023-shreyamgupta_78aa423a-BA_before_LU-694c.wav',
#  'anot--file_path': 'reports/pnoi_sync_data_v9/shreyamgupta_78aa423a/pnoistor_feb2023-shreyamgupta_78aa423a-BA_before_LU-694c.txt'}

# %%
pd.read_csv(PNOI_SYNC_CSV_PATH)
# Out:
#      Unnamed: 0     fs                 sub_id  file_class  \
# 0             0  16000  shreyamgupta_78aa423a  _before_LU
# 1             1  16000  shreyamgupta_78aa423a  _before_RU
# 2             2  16000  shreyamgupta_78aa423a  _before_LL
# 3             3  16000  shreyamgupta_78aa423a  _before_RL
# 4             4  16000  sannashoukat_5213fe84  _before_LU
# ..          ...    ...                    ...         ...
# 134         134  16000       sujatan_bdd161b6   _after_RL
# 135         135  16000       lokeshk_90b4871a  _before_LU
# 136         136  16000       lokeshk_90b4871a  _before_RU
# 137         137  16000       lokeshk_90b4871a  _before_LL
# 138         138  16000       lokeshk_90b4871a  _before_RL
#
#                                       audio--file_path  \
# 0    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 1    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 2    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 3    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 4    reports/pnoi_sync_data_v9/sannashoukat_5213fe8...
# ..                                                 ...
# 134  reports/pnoi_sync_data_v9/sujatan_bdd161b6/pno...
# 135  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
# 136  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
# 137  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
# 138  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
#
#                                        anot--file_path
# 0    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 1    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 2    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 3    reports/pnoi_sync_data_v9/shreyamgupta_78aa423...
# 4    reports/pnoi_sync_data_v9/sannashoukat_5213fe8...
# ..                                                 ...
# 134  reports/pnoi_sync_data_v9/sujatan_bdd161b6/pno...
# 135  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
# 136  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
# 137  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
# 138  reports/pnoi_sync_data_v9/lokeshk_90b4871a/pno...
#
# [139 rows x 6 columns]
